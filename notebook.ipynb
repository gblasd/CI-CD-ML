# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load data

# %%
drug_df = pd.read_csv('Data/drug200.csv')
drug_df = drug_df.sample(frac=1)
drug_df.head(3)
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 193   72   M     LOW        HIGH    6.769  drugC
# 75    26   M     LOW      NORMAL   20.909  DrugY
# 58    60   M  NORMAL      NORMAL   10.091  drugX

# %% [markdown]
# ### Split data

# %%
from sklearn.model_selection import train_test_split

# %%
X = drug_df.drop('Drug', axis=1).values
y = drug_df.Drug.values

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=124
)

# %% [markdown]
# ### Pipeline ML

# %%
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

cat_col = [1,2,3]
num_col = [0,4]

transform = ColumnTransformer(
    [
        ("encoder", OrdinalEncoder(), cat_col),
        ("num_imputer", SimpleImputer(strategy="median"), num_col),
        ("num_scaler", StandardScaler(), num_col),
    ]
)
pipe = Pipeline(
    steps=[
        ("preprocessing", transform),
        ("model", RandomForestClassifier(n_estimators=100, random_state=125)),
    ]
)
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('encoder', OrdinalEncoder(),
#                                                   [1, 2, 3]),
#                                                  ('num_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   [0, 4]),
#                                                  ('num_scaler',
#                                                   StandardScaler(), [0, 4])])),
#                 ('model', RandomForestClassifier(random_state=125))])

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import accuracy_score, f1_score

predictions = pipe.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
f1 = f1_score(y_test, predictions, average="macro")

print("Accuracy:", str(round(accuracy, 2) * 100) + "%", "F1:", round(f1, 2))
# Out:
# Accuracy: 95.0% F1: 0.88

# %% [markdown]
# Save metrics on Results folder

# %%
with open("Results/metrics.txt", "w") as outfile:
    outfile.write(f"\nAccuracy = {round(accuracy, 2)}, F1 Score = {round(f1, 2)}.")

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(y_test, predictions, labels=pipe.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipe.classes_)
disp.plot()
plt.savefig("Results/model_results.png", dpi=120)
# Out:
# Unable to revert mtime: /Library/Fonts
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Save the model

# %%
import skops.io as sio

sio.dump(pipe, "Model/drug_pipeline.skops")

# %%
# 1. Get the list of untrusted/unknown types in the file
unknown_types = sio.get_untrusted_types(file="Model/drug_pipeline.skops")

# 2. Review the contents of 'unknown_types'
print(unknown_types)

# 3. If you verify the types are safe, pass the list as the trusted argument
loaded_model = sio.load("Model/drug_pipeline.skops", trusted=unknown_types)
# Out:
# ['numpy.dtype']

# %%
loaded_model
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('encoder', OrdinalEncoder(),
#                                                   [1, 2, 3]),
#                                                  ('num_imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   [0, 4]),
#                                                  ('num_scaler',
#                                                   StandardScaler(), [0, 4])])),
#                 ('model', RandomForestClassifier(random_state=125))])
